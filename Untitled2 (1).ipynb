# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
from google.colab import drive

drive.mount('/content/drive')

import os

os.chdir('/content/drive/My Drive/VERIYAPILARI_ISTKA')

# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/VERIYAPILARI_ISTKA

# %%
while True:

  try :

    print("\n \t \t HASTANE OTOMASYONU \t \t")

    print("1 - Hasta Kayit \n")

    print("2 - Doktor Giris \n")

    print("3 - Doktor Kayit \n")

    print("0 - Programı Kapat \n")

    kayitlikullanici="esenwhoaw"

    kayitlisifre="Esen.2418"

    islem=input("İstediğiniz işlemi giriniz : ")

    if islem=="0":

     print("\nİyi günler dileriz...")

     break

    elif islem=="1":

     print("\n \t \t HASTA KAYIT FORMU \t \t")

     hastaadi=input("\nHastanın Adı : ")

     hastasoyadi=input("\nHastanın Soyadı : ")

     hastanintcsi=int(input("\nHastanı TC Kimlik Numarası :  "))

     if not hastaadi or not hastasoyadi:

      print("\nEksik veri girdiniz.")

     elif len(str(hastanintcsi))!=11:

      print("\nTC'yi 11 karakterden eksik veya fazla girdiniz!")

     else:

      print("\nHastanın kaydı başarıyla oluşturuldu.")

      continue

    elif islem=="2":

     print("\n \t \t DOKTOR GİRİŞ FORMU \t \t")

     doktorkullanici=input("\nKullanıcı Adınızı Giriniz :")

     doktorsifre=input("\nŞifrenizi Giriniz :")

     if doktorkullanici==kayitlikullanici and doktorsifre==kayitlisifre:

        print("\nGiriş Başarılı!")

     elif not doktorkullanici or not doktorsifre:

       print("\nEksik veri girdiniz.")

     else:

      print("\nKullanıcı adını veya şifreyi yanlış girdiniz.")

    elif islem=="3":

     print("\n \t \t DOKTOR KAYIT FORMU \t \t")

     doktoradi=input("\nDoktorun Adı : ")

     doktorunsoyadi=input("\nDoktorun Soyadı : ")

     doktoruntcsi=int(input("\nDoktorun TC Kimlik Numarası :  "))

     print("\nKlinikler : \n 1 - KBB \n 2 - Göz Hastalıkları \n 3 - Deri ve Zührevi Hastalıkları \n 4 - Endodonti \n 5 - Kadın Doğum \n 6 - Kardiyoloji \n")

     klinik=input("Doktorun Bölümü :  ")

     if not doktoradi or not doktorunsoyadi or not doktoruntcsi or not klinik:

      print("\nEksik veri girdiniz.")

     elif len(str(doktoruntcsi))!=11:

      print("\nTC'yi 11 karakterden eksik veya fazla girdiniz!")

     else :

      if klinik=="1":

       print("\nDoktorun Bölümü :  KBB")
       print("\nDoktor Kaydı Tamamlanmıştır. \n")

      elif klinik=="2":

       print("\nDoktorun Bölümü :  Göz Hastalıkları")
       print("\nDoktor Kaydı Tamamlanmıştır. \n")

      elif klinik=="3":

       print("\nDoktorun Bölümü :  Deri ve Zührevi Hastalıkları")
       print("\nDoktor Kaydı Tamamlanmıştır. \n")

      elif klinik=="4":

       print("\nDoktorun Bölümü :  Endodonti")
       print("\nDoktor Kaydı Tamamlanmıştır. \n")


      elif klinik=="5":

       print("\nDoktorun Bölümü :  Kadın Doğum")
       print("\nDoktor Kaydı Tamamlanmıştır. \n")


      elif klinik=="6":

       print("\nDoktorun Bölümü :  Kardiyoloji")
       print("\nDoktor Kaydı Tamamlanmıştır. \n")


      else:

       print(f"\nDoktorun Bölümü :  {klinik}")
       print("\nDoktor Kaydı Tamamlanmıştır. \n")


  except ValueError:
   print("\n Veri Girmediniz!")
# Out:
#  	 	 HASTANE OTOMASYONU
# 1 - Hasta Kayit
#
# 2 - Doktor Giris
#
# 3 - Doktor Kayit
#
# 0 - Programı Kapat
#
# İstediğiniz işlemi giriniz : 1
#
#  	 	 HASTA KAYIT FORMU
#
# Hastanın Adı : Esen
#
# Hastanın Soyadı : Er
#
# Hastanı TC Kimlik Numarası :  47586914253
#
# Hastanın kaydı başarıyla oluşturuldu.
#
#  	 	 HASTANE OTOMASYONU
# 1 - Hasta Kayit
#
# 2 - Doktor Giris
#
# 3 - Doktor Kayit
#
# 0 - Programı Kapat
#
# İstediğiniz işlemi giriniz : 1
#
#  	 	 HASTA KAYIT FORMU
#
# Hastanın Adı : Esen
#
# Hastanın Soyadı : Er
#
# Hastanı TC Kimlik Numarası :  4758691425
#
# TC'yi 11 karakterden eksik veya fazla girdiniz!
#
#  	 	 HASTANE OTOMASYONU
# 1 - Hasta Kayit
#
# 2 - Doktor Giris
#
# 3 - Doktor Kayit
#
# 0 - Programı Kapat
#
# İstediğiniz işlemi giriniz : 1
#
#  	 	 HASTA KAYIT FORMU
#
# Hastanın Adı : Esen
#
# Hastanın Soyadı :
#
# Hastanı TC Kimlik Numarası :  47586914253
#
# Eksik veri girdiniz.
#
#  	 	 HASTANE OTOMASYONU
# 1 - Hasta Kayit
#
# 2 - Doktor Giris
#
# ...
